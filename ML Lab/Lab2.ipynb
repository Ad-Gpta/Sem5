# %%
#example 1
# importing matplotlib module
from matplotlib import pyplot as plt
# x-axis values
x = [5, 2, 9, 4, 7]
# Y-axis values
y = [10, 5, 8, 4, 2]
# Function to plot
plt.plot(x,y)
# function to show the plot
plt.show()
# Function to plot the bar
plt.bar(x,y)
# function to show the plot
plt.show()
# Function to plot scatter
plt.scatter(x, y)
# function to show the plot
plt.show()

# %%
import numpy as np
arr = np.random.randint(10, size = 10)
print(arr)
plt.hist(arr)
arr = [1, 2, 3, 4 ,1]
plt.hist(arr)

"""
So in a histogram: 
x axis is the bins (ranges of numbers)
y axis is the frequency (number of times a number appears)
"""
# Out:
# [8 6 3 3 8 0 4 7 7 6]
# '\nSo in a histogram: \nx axis is the bins (ranges of numbers)\ny axis is the frequency (number of times a number appears)\n'

# %%
x = np.random.normal(170, 1, 250) 
#(mean/peak of normal distribution, std deviation,len of array)
plt.hist(x)
plt.show()

# %%
x = np.random.randint(100, size = 100)
y = np.random.randint(100, size = 100)
# Function to plot scatter
plt.scatter(x, y, color = 'mediumseagreen')
# function to show the plot
plt.show()

# %% [markdown]
# Q1)
# Follow along with these steps:
# a) Create a figure object called fig using plt.figure()
# b) Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# c) Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1]) # add_axes([left, bottom, width, height])
#fig.show()
x = np.arange(0,100) #arranges all nos from 0 to 100
y = x*2
ax.plot(x,y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph')
plt.show()

# %% [markdown]
# Q2)
# Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2]
# respectively. Now plot (x,y) on both axes. And call your figure object to show it.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax1.plot(x,y)
ax2.plot(x,y)
plt.show()

# %% [markdown]
# Q3)
# Use the company sales dataset csv file, read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties: –
# a. X label name = Month Number
# b. Y label name = Total profit

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
"""
with open("/home/AIML_Student/Documents/B34_aiml/Lab2/company_sales_data.csv","rt") as f:
    data = csv.reader(f)
    for r in data: 
        print(r)
        break
"""
cols = ["month_number","total_profit"]
df = pd.read_csv("/home/AIML_Student/Documents/B34_aiml/Lab2/company_sales_data.csv", usecols = cols)
print(df)

plt.plot(df.month_number, df.total_profit)
plt.xlabel('Month number')
plt.ylabel('Total profit')
plt.title('Year summary')
plt.show()
# Out:
#     month_number  total_profit
# 0              1        211000
# 1              2        183300
# 2              3        224700
# 3              4        222700
# 4              5        209600
# 5              6        201400
# 6              7        295500
# 7              8        361400
# 8              9        234000
# 9             10        266700
# 10            11        412800
# 11            12        300200

# %% [markdown]
# Q4)
# Use the company sales dataset csv file, get total profit of all months and show line plot with the following style properties:–
# a. Line Style dotted and Line-color should be red
# b. Show legend at the lower right location.
# c. X label name = Month Number
# d. Y label name = Sold units number
# e. Add a circle marker.
# f. Line marker color as read
# g. Line width should be 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
cols = ["month_number","total_profit"]
df = pd.read_csv("/home/AIML_Student/Documents/B34_aiml/Lab2/company_sales_data.csv", usecols = cols)
plt.plot(df.month_number, df.total_profit,linewidth = 3, linestyle = 'dotted', color='r', marker = 'o')
plt.legend(['sales'], loc = 'lower right')
plt.xlabel('Month number')
plt.ylabel('Sold units number')
plt.title('Year summary')
plt.show()
